# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=500, centers=2, n_features=2, random_state=0)

# %%
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()

# %%
from utils.analysis import run_model

run_model(model, X, y)
# Out:
# Summary for GaussianNB():
# Training time: 0.000553131103515625
# Prediction time: 0.000152587890625
# Quality. Accuracy: 0.9575757575757575, Precision: 0.9487179487179487, Recall 0.961038961038961, F1: 0.9548387096774195

# %%
from sklearn.datasets import make_classification

X, y = make_classification(
    n_samples=1000, 
    n_features=2, 
    n_informative=2,
    n_redundant=0,
    n_repeated=0,
    n_classes=2, 
    n_clusters_per_class=2,
    class_sep=0.8,
    random_state=42
)

# %%
run_model(model, X, y)
# Out:
# Summary for GaussianNB():
# Training time: 0.0016832351684570312
# Prediction time: 0.0003325939178466797
# Quality. Accuracy: 0.8151515151515152, Precision: 0.8732394366197183, Recall 0.7425149700598802, F1: 0.8025889967637541
