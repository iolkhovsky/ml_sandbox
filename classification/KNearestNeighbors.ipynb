# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=500, centers=2, n_features=2, random_state=0)

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(
    n_neighbors=5,
    weights="uniform"
)

# %%
from utils.analysis import run_model

run_model(model, X, y)
# Out:
# Summary for KNeighborsClassifier():
# Training time: 0.002137899398803711
# Prediction time: 0.018399477005004883
# Quality. Accuracy: 0.9515151515151515, Precision: 0.9367088607594937, Recall 0.961038961038961, F1: 0.9487179487179488

# %%
from sklearn.datasets import make_classification

X, y = make_classification(
    n_samples=1000, 
    n_features=2, 
    n_informative=2,
    n_redundant=0,
    n_repeated=0,
    n_classes=2, 
    n_clusters_per_class=2,
    class_sep=0.8,
    random_state=42
)

# %%
run_model(model, X, y)
# Out:
# Summary for KNeighborsClassifier():
# Training time: 0.00429224967956543
# Prediction time: 0.022455215454101562
# Quality. Accuracy: 0.8696969696969697, Precision: 0.9492753623188406, Recall 0.7844311377245509, F1: 0.859016393442623
