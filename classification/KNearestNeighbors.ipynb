# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=1000, centers=2, n_features=2, random_state=0)

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(
    n_neighbors=5,
    weights="uniform"
)

# %%
from utils.analysis import run_model

run_model(model, X, y)
# Out:
# Summary for KNeighborsClassifier():
# Training time: 0.00046181678771972656
# Prediction time: 0.006228446960449219
# Quality. Accuracy: 0.9515151515151515, Precision: 0.9454545454545454, Recall 0.9570552147239264, F1: 0.9512195121951219
